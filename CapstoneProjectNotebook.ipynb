# %% [markdown]
# # Capstone Project - Battle of the Neighborhoods (Part 2)

# %% [markdown]
# ### Table of Contents
# * Introduction: Business Problem
# * Data
# * Methodology
# * Analysis
# * Results

# %% [markdown]
# ### Introduction

# %% [markdown]
# This notebook is part of the Capstone Project for IBM's Data Science Professional Certificate. For this project, I will be exploring a hypothetical request regarding Japanese restaurants in New York City. As of 2011, about 20,000 Japanese were living in New York City and a total of around 45,000 Japanese were living in the Greater New York City area. Most of this population consists of students, artists and expatriate business workers who are typically posted within the US for three to five years. While the Japanese in New York comprise a smaller demographic than the Chinese or Korean populations respectively, the popularity of Japanese cuisine means that there will never be a lack of demand, both from the largest Japanese community on the East Coast and from the general public, tourists and locals alike.
#
# I will try to detect the locations of already existing Japanese restaurants within and around New York (extending out to Bergen County, NJ and Long Island). This data will be used to scope out locations which have a lesser concentration of Japanese restaurants.
#
# **Note: This project can be further expanded by clustering the Japanese population in the state of New York by city and plotting the cluster of population against cluster of restaurants. This would lead to
# a much more accurate prediction, but will not be used in this report due to time constraints.**

# %% [markdown]
# #### Target Audience
#
# This report and its findings will be useful to anyone wanting to get a detailed overview of Japanese cuisine within New York City bounds and for anyone who wishes to see how data is used to provide prospective small business owners and restauranteurs with the information needed to make informed decisions.

# %% [markdown]
# ### Data

# %% [markdown]
# Based on definition of our problem, factors that will influence our decision are:
#
# * Number of existing Japanese restaurants in the New York City area.
# * Location (latitude and longitude) of Japanese restaurants.
# * Concentration of Japanese population in New York and neighborhoods around New York. (again, not used due to time constraints)
#
# The following data sources will be needed to extract/generate the required information:
#
# * Geo coordinates of the cities of New York, NY and Scarsdale, NY will be obtained using Geopy Nominatim
# * Number of restaurants and their type and location in every neighborhood will be obtained using Foursquare API
#
# **Note: Since Foursquare explore_venue API returns only 50 results per search, I am using one more search query with the city of Scarsdale, NY to get more coverage. Scarsdale has a sizable Japanese community consisting of households with first and second generations, as opposed to communities in the New York Metropolitan area that normally consist of expatriates who are assigned to live there for only three to five years.**

# %% [markdown]
# #### Let's Begin - Importing Required Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Folium and geopy installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium and geopy installed
# Libraries imported.

# %% [markdown]
# #### Now, let's Analyze and Cluster Japanese Restaurants around New York - Obtain Geographical Coordinates for New York and Scarsdale Using Geopy

# %%
address = 'New York, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude_nyc = location.latitude
longitude_nyc = location.longitude
print('The geograpical coordinate of New York are {}, {}.'.format(latitude_nyc, longitude_nyc))
# Out:
# The geograpical coordinate of New York are 40.7127281, -74.0060152.

# %%
address = 'Scarsdale, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude_scr = location.latitude
longitude_scr = location.longitude
print('The geograpical coordinate of Scarsdale are {}, {}.'.format(latitude_scr, longitude_scr))
# Out:
# The geograpical coordinate of Scarsdale are 40.9690798, -73.7635316.

# %% [markdown]
# #### Define Foursquare Credentials

# %%
CLIENT_ID = 'HFIG5BPXXFM0ISH1XNCAY5K52B5FPFCBBI51Z04UT13U412X' # your Foursquare ID
CLIENT_SECRET = 'CBSE1R4EOGTXSC2J1HKW4R3TJMYHXIFQGLY4PHIA0ZAE1O0A' # your Foursquare Secret
VERSION = '20200804' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: HFIG5BPXXFM0ISH1XNCAY5K52B5FPFCBBI51Z04UT13U412X
# CLIENT_SECRET:CBSE1R4EOGTXSC2J1HKW4R3TJMYHXIFQGLY4PHIA0ZAE1O0A

# %% [markdown]
# #### The Fun Part - Search for Japanese Restaurants Using Foursquare API

# %% [markdown]
# * Foursqaure API ~venues/search option
# * search_query = 'Japanese'
# * category = '4d4b7105d754a06374d81259' # Food
#
# **Note: Refer to http://developer.foursquare.com/docs/api-reference/venues/search/ for documentation on Foursquare venue/search.**

# %%
# Foursquare venues->search -> New York, NY

LIMIT = 100 # limit of number of venues returned by Foursquare API (Maximum 50 resposes)
search_query = 'Japanese'
radius =100000 # define radius
category = '4d4b7105d754a06374d81259' # Food

# create URL
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    category,
    latitude_nyc, 
    longitude_nyc,
    radius, 
    LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=HFIG5BPXXFM0ISH1XNCAY5K52B5FPFCBBI51Z04UT13U412X&client_secret=CBSE1R4EOGTXSC2J1HKW4R3TJMYHXIFQGLY4PHIA0ZAE1O0A&v=20200804&query=Japanese&categoryId=4d4b7105d754a06374d81259&ll=40.7127281,-74.0060152&radius=100000&limit=100'

# %%
# get request for results
results = requests.get(url).json()
results  # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5f4a64f7d7237d7d56dc833c'},
#  'response': {'venues': [{'id': '4b78ac62f964a52047dd2ee3',
#     'name': 'Zutto Japanese American Pub',
#     'location': {'address': '77 Hudson St',
#      'crossStreet': 'Harrison St and Worth St.',
#      'lat': 40.7185655837561,
#      'lng': -74.00891273768076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7185655837561,
#        'lng': -74.00891273768076},
#       {'label': 'entrance', 'lat': 40.718459, 'lng': -74.009006}],
#      'distance': 694,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['77 Hudson St (Harrison St and Worth St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '867441',
#      'url': 'https://www.seamless.com/menu/zutto-77-hudson-st-new-york/867441?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=867441',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '42701794'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e6aaea3d164c37bf4b2539d',
#     'name': 'Sumo Japanese Cuisine',
#     'location': {'address': '104 John St',
#      'crossStreet': 'at Cliff St',
#      'lat': 40.70771408081055,
#      'lng': -74.0062255859375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70771408081055,
#        'lng': -74.0062255859375}],
#      'distance': 558,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 John St (at Cliff St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '42055e00f964a5206e1f1fe3',
#     'name': 'EN Japanese Brasserie',
#     'location': {'address': '435 Hudson St',
#      'crossStreet': 'at Leroy St.',
#      'lat': 40.730297083045144,
#      'lng': -74.00695716911856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.730297083045144,
#        'lng': -74.00695716911856}],
#      'distance': 1957,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['435 Hudson St (at Leroy St.)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1536134',
#      'url': 'https://www.seamless.com/menu/en-japanese-brasserie-435-hudson-st-new-york/1536134?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1536134',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '103057123'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b7736b9f964a5206b882ee3',
#     'name': 'Emperor Japanese Tapas Shabu',
#     'location': {'address': '96 Bowery',
#      'crossStreet': 'btw Hester & Grand',
#      'lat': 40.71758147589841,
#      'lng': -73.99533004707291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71758147589841,
#        'lng': -73.99533004707291}],
#      'distance': 1051,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['96 Bowery (btw Hester & Grand)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '5f3089ef7150dc431d2d1bd1',
#     'name': 'Pinklady Japanese Cheese Tart',
#     'location': {'address': '11 Mott St',
#      'lat': 40.713986,
#      'lng': -73.998741,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.713986,
#        'lng': -73.998741}],
#      'distance': 629,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['11 Mott St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2139318',
#      'url': 'https://www.seamless.com/menu/pinklady-cheese-tart-11-mott-st-new-york/2139318?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2139318',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '45a38e32f964a520ee401fe3',
#     'name': 'SUteiShi Japanese Restaurant',
#     'location': {'address': '24 Peck Slip',
#      'crossStreet': 'btwn Front & Water St',
#      'lat': 40.707807603285566,
#      'lng': -74.0018892288208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.707807603285566,
#        'lng': -74.0018892288208},
#       {'label': 'entrance', 'lat': 40.707755, 'lng': -74.001838}],
#      'distance': 649,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24 Peck Slip (btwn Front & Water St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '281525',
#      'url': 'https://www.seamless.com/menu/suteishi-24-peck-slip-new-york/281525?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=281525',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '52817650'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '5464f27c498e2e01c60151af',
#     'name': 'Kaede Japanese Restaurant',
#     'location': {'address': '90 Chambers St',
#      'lat': 40.71462286117167,
#      'lng': -74.00727042164348,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71462286117167,
#        'lng': -74.00727042164348}],
#      'distance': 236,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['90 Chambers St',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '298297',
#      'url': 'https://www.seamless.com/menu/kaede-90-chambers-st-new-york/298297?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=298297',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4e4c34bd4101d0d7a71f7d',
#     'name': 'Aoi Japanese Restaurant',
#     'location': {'address': '325 Broadway',
#      'lat': 40.71612035753943,
#      'lng': -74.00527813637986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71612035753943,
#        'lng': -74.00527813637986}],
#      'distance': 382,
#      'postalCode': '10007',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['325 Broadway',
#       'New York, NY 10007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4f326c4819836c91c7d658ff',
#     'name': 'Nagoya Japanese Restaurant',
#     'location': {'address': '59 Nassau St',
#      'lat': 40.709251403808594,
#      'lng': -74.00879669189453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709251403808594,
#        'lng': -74.00879669189453}],
#      'distance': 452,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 Nassau St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c45d523dd1f2d7f64c681f9',
#     'name': 'Mana Japanese',
#     'location': {'address': '59 Nassau St',
#      'lat': 40.709251403808594,
#      'lng': -74.00879669189453,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709251403808594,
#        'lng': -74.00879669189453}],
#      'distance': 452,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 Nassau St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ba7fa26f964a5208cc339e3',
#     'name': 'Ozu Japanese Cuisine & Lounge',
#     'location': {'address': '78 Clark St',
#      'crossStreet': 'btw Henry & Hicks',
#      'lat': 40.697513,
#      'lng': -73.993369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.697513,
#        'lng': -73.993369}],
#      'distance': 2001,
#      'postalCode': '11201',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['78 Clark St (btw Henry & Hicks)',
#       'Brooklyn, NY 11201',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '315168',
#      'url': 'https://www.seamless.com/menu/ozu-japanese-cuisine-78-clark-st-brooklyn/315168?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=315168',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '76879661'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4c4fbdbd413c4cc66869c3',
#     'name': 'Nagoya Japanese Restaurant',
#     'location': {'address': '49 Fulton St',
#      'lat': 40.708168029785156,
#      'lng': -74.00395965576172,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.708304,
#        'lng': -74.004433},
#       {'label': 'display',
#        'lat': 40.708168029785156,
#        'lng': -74.00395965576172}],
#      'distance': 536,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['49 Fulton St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4a8cb3fff964a520ed0e20e3',
#     'name': "Ruby's Japanese & Thai",
#     'location': {'address': '259 1st Ave',
#      'crossStreet': 'at E 15th St.',
#      'lat': 40.732248999999996,
#      'lng': -73.982291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.732248999999996,
#        'lng': -73.982291},
#       {'label': 'entrance', 'lat': 40.732195, 'lng': -73.982163}],
#      'distance': 2954,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['259 1st Ave (at E 15th St.)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4f326cc019836c91c7d689dc',
#     'name': 'Koi Japanese Restaurant',
#     'location': {'address': '265 Canal St',
#      'lat': 40.718785,
#      'lng': -74.001024,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718785,
#        'lng': -74.001024}],
#      'distance': 794,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['265 Canal St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '55fa0bd4498e3a875e4e34ff',
#     'name': 'AA Japanese Ramen',
#     'location': {'address': '45 Bayard St',
#      'lat': 40.71524803870191,
#      'lng': -73.9971465386204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71524803870191,
#        'lng': -73.9971465386204}],
#      'distance': 799,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['45 Bayard St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '55a59bace4b013909087cb24',
#       'name': 'Ramen Restaurant',
#       'pluralName': 'Ramen Restaurants',
#       'shortName': 'Ramen',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4c4cf3bd413c4cc6685628',
#     'name': 'Kokura Japanese Restaurant',
#     'location': {'address': '19 S William St',
#      'lat': 40.70439529418945,
#      'lng': -74.010498046875,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70439529418945,
#        'lng': -74.010498046875}],
#      'distance': 1001,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['19 S William St',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '3fd66200f964a520e0e81ee3',
#     'name': 'Wave Japanese Restaurant',
#     'location': {'address': '80 Broad St',
#      'crossStreet': 'btw West Thames and 3rd St',
#      'lat': 40.704249,
#      'lng': -74.011569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.704249,
#        'lng': -74.011569}],
#      'distance': 1053,
#      'postalCode': '10004',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['80 Broad St (btw West Thames and 3rd St)',
#       'New York, NY 10004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bde28866c1b9521ac51ad0f',
#     'name': 'Ichiban Japanese Restaurant',
#     'location': {'address': '409 8th Ave',
#      'crossStreet': '31st Street',
#      'lat': 40.750082040220704,
#      'lng': -73.99501732393351,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750082040220704,
#        'lng': -73.99501732393351}],
#      'distance': 4260,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['409 8th Ave (31st Street)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bba1c4b1261d13a243cea98',
#     'name': 'Narita Japanese Restaurant',
#     'location': {'address': '10708 70th Rd',
#      'crossStreet': 'btw Austin St & Queens Blvd',
#      'lat': 40.72079733718884,
#      'lng': -73.84563896863934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72079733718884,
#        'lng': -73.84563896863934}],
#      'distance': 13561,
#      'postalCode': '11375',
#      'cc': 'US',
#      'city': 'Forest Hills',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10708 70th Rd (btw Austin St & Queens Blvd)',
#       'Forest Hills, NY 11375',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4a85b541f964a520fdfe1fe3',
#     'name': 'Tataki Japanese Restaurant',
#     'location': {'address': '3 Lispenard St',
#      'lat': 40.720596,
#      'lng': -74.00493,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.720596,
#        'lng': -74.00493},
#       {'label': 'entrance', 'lat': 40.720581, 'lng': -74.004927}],
#      'distance': 880,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3 Lispenard St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '64534',
#      'url': 'https://www.seamless.com/menu/tataki-japanese-restaurant-3-lispenard-st-new-york/64534?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=64534',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ef0d81fbe7ba3ed7c2296d2',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '321 W 44th St',
#      'crossStreet': 'btwn 8th & 9th Ave',
#      'lat': 40.75904160050783,
#      'lng': -73.99004327793013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75904160050783,
#        'lng': -73.99004327793013}],
#      'distance': 5328,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['321 W 44th St (btwn 8th & 9th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2250480',
#      'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-321-w-44th-st-new-york/2250480?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2250480',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '5006eaf1e4b0d9eeb5cd67ef',
#     'name': 'Atami Japanese Fusion',
#     'location': {'address': '1167 2nd Ave',
#      'lat': 40.762158444759486,
#      'lng': -73.96317393360368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762158444759486,
#        'lng': -73.96317393360368}],
#      'distance': 6582,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1167 2nd Ave',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '461198',
#      'url': 'https://www.seamless.com/menu/atami-japanese-fusion-1167-2nd-ave-new-york/461198?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=461198',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '48208c8cf964a520894f1fe3',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '805 3rd Ave',
#      'crossStreet': 'btwn E 49th & E 50th St',
#      'lat': 40.755730504250046,
#      'lng': -73.9708969487331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755730504250046,
#        'lng': -73.9708969487331}],
#      'distance': 5629,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['805 3rd Ave (btwn E 49th & E 50th St)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2251148',
#      'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-805-3rd-ave-new-york/2251148?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251148',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4e4aa6bd4101d0d7a6fc27',
#     'name': 'Asahi Japanese Cuisine',
#     'location': {'address': '311 W 48th St',
#      'lat': 40.76150131225586,
#      'lng': -73.98757934570312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76150131225586,
#        'lng': -73.98757934570312}],
#      'distance': 5647,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['311 W 48th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4baab031f964a520fc7f3ae3',
#     'name': 'Chikurin Japanese Restaurant',
#     'location': {'address': '1777 Ocean Ave',
#      'crossStreet': 'at Ave M',
#      'lat': 40.61873004377748,
#      'lng': -73.95481085897256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.61873004377748,
#        'lng': -73.95481085897256},
#       {'label': 'entrance', 'lat': 40.618744, 'lng': -73.954855}],
#      'distance': 11321,
#      'postalCode': '11230',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1777 Ocean Ave (at Ave M)',
#       'Brooklyn, NY 11230',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299694',
#      'url': 'https://www.seamless.com/menu/chikurin-japanese-restaurant-1777-ocean-ave-brooklyn/299694?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299694',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fd91c44e4b0d9021d3ee7ca',
#     'name': "Ai's Sushi Japanese Restaurant",
#     'location': {'address': '374 W 46th St',
#      'crossStreet': '9th Ave',
#      'lat': 40.760777000000004,
#      'lng': -73.990584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760777000000004,
#        'lng': -73.990584}],
#      'distance': 5504,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['374 W 46th St (9th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b25858af964a520437324e3',
#     'name': 'Ten Japanese Cuisine',
#     'location': {'address': '440 7th Ave',
#      'crossStreet': 'at 15th St',
#      'lat': 40.663360452481534,
#      'lng': -73.98454249519556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.663360452481534,
#        'lng': -73.98454249519556},
#       {'label': 'entrance', 'lat': 40.663434, 'lng': -73.984631}],
#      'distance': 5786,
#      'postalCode': '11215',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['440 7th Ave (at 15th St)',
#       'Brooklyn, NY 11215',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '67534',
#      'url': 'https://www.seamless.com/menu/ten-japanese-cuisine-440-7th-ave-brooklyn/67534?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=67534',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fb93e46e4b0d0dd7eb666c6',
#     'name': 'Amura Japanese Cuisine',
#     'location': {'address': '1567 2nd Ave',
#      'lat': 40.77492786445796,
#      'lng': -73.95393883303005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77492786445796,
#        'lng': -73.95393883303005}],
#      'distance': 8199,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1567 2nd Ave',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '268954',
#      'url': 'https://www.seamless.com/menu/amura-1567-2nd-ave-new-york/268954?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=268954',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b7c90acf964a520569b2fe3',
#     'name': 'Tomo Japanese Cuisine',
#     'location': {'address': '86-12 A 37th Ave',
#      'crossStreet': 'btwn 86th & 87th St',
#      'lat': 40.75016941828497,
#      'lng': -73.88014969825647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75016941828497,
#        'lng': -73.88014969825647}],
#      'distance': 11406,
#      'postalCode': '11372',
#      'cc': 'US',
#      'city': 'Jackson Heights',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['86-12 A 37th Ave (btwn 86th & 87th St)',
#       'Jackson Heights, NY 11372',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4a86ffb1f964a520090220e3',
#     'name': 'Osaka Japanese Restaurant',
#     'location': {'address': '24-25 Broadway',
#      'lat': 40.763054033139525,
#      'lng': -73.9276589498208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763054033139525,
#        'lng': -73.9276589498208}],
#      'distance': 8664,
#      'postalCode': '11106',
#      'cc': 'US',
#      'neighborhood': 'Astoria',
#      'city': 'Astoria',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24-25 Broadway',
#       'Astoria, NY 11106',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '71415',
#      'url': 'https://www.seamless.com/menu/osaka-japanese-fusion-2524-broadway-ave-astoria/71415?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=71415',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bcb5030937ca593f44aa992',
#     'name': 'Chikurin Japanese Restaurant',
#     'location': {'address': '39-11 Queens Blvd',
#      'lat': 40.74433135986328,
#      'lng': -73.92537689208984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74433135986328,
#        'lng': -73.92537689208984}],
#      'distance': 7658,
#      'postalCode': '11104',
#      'cc': 'US',
#      'city': 'Sunnyside',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['39-11 Queens Blvd',
#       'Sunnyside, NY 11104',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c3b4ae416cb2d7f8b9c02a9',
#     'name': 'Tomo Japanese Cafe',
#     'location': {'address': '8914 Queens Blvd',
#      'crossStreet': 'btwn 56th & 57th Ave.',
#      'lat': 40.734630357172136,
#      'lng': -73.87418166369174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734630357172136,
#        'lng': -73.87418166369174}],
#      'distance': 11386,
#      'postalCode': '11373',
#      'cc': 'US',
#      'city': 'Elmhurst',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['8914 Queens Blvd (btwn 56th & 57th Ave.)',
#       'Elmhurst, NY 11373',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1093832',
#      'url': 'https://www.seamless.com/menu/tomo-japanese-cafe-8914-queens-blvd-elmhurst/1093832?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1093832',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b5de807f964a520d47229e3',
#     'name': 'Tokyo Japanese Kitchen',
#     'location': {'address': '38-01 31st St',
#      'lat': 40.75345047269599,
#      'lng': -73.9323436512949,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75345047269599,
#        'lng': -73.9323436512949}],
#      'distance': 7692,
#      'postalCode': '11101',
#      'cc': 'US',
#      'city': 'Astoria',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['38-01 31st St',
#       'Astoria, NY 11101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4acea43cf964a5208ad120e3',
#     'name': "Raku It's Japanese II",
#     'location': {'address': '57 W 76th St',
#      'crossStreet': 'at Columbus Ave',
#      'lat': 40.77999142937673,
#      'lng': -73.97661045826288,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77999142937673,
#        'lng': -73.97661045826288}],
#      'distance': 7887,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['57 W 76th St (at Columbus Ave)',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '284075',
#      'url': 'https://www.seamless.com/menu/raku-ii-japanese-restaurant-57-w-76th-st-new-york/284075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=284075',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '96183310'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '598417dadb1d816c64238a96',
#     'name': 'Yoi Sushi Japanese 良日本料理',
#     'location': {'address': '133-22 39th Ave',
#      'lat': 40.7589929,
#      'lng': -73.83364499999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7589929,
#        'lng': -73.83364499999999}],
#      'distance': 15424,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['133-22 39th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2188057',
#      'url': 'https://www.seamless.com/menu/yoi-sushi-133-22-39th-ave-flushing/2188057?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2188057',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '434133555'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b68bee0f964a520808a2be3',
#     'name': 'Koyama Japanese Restaurant',
#     'location': {'address': '458 Palisade Ave',
#      'lat': 40.819594,
#      'lng': -73.988568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.819594,
#        'lng': -73.988568},
#       {'label': 'entrance', 'lat': 40.819737, 'lng': -73.988594}],
#      'distance': 11986,
#      'postalCode': '07010',
#      'cc': 'US',
#      'city': 'Cliffside Park',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['458 Palisade Ave',
#       'Cliffside Park, NJ 07010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c695c7f2c29d13a4cf60a41',
#     'name': 'Asakura Japanese Restaurant',
#     'location': {'address': '1948 86th St',
#      'lat': 40.605028000000004,
#      'lng': -73.999387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.605028000000004,
#        'lng': -73.999387},
#       {'label': 'entrance', 'lat': 40.605082, 'lng': -73.99933}],
#      'distance': 12002,
#      'postalCode': '11214',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1948 86th St',
#       'Brooklyn, NY 11214',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b787863f964a52080d02ee3',
#     'name': 'Shiki Japanese Hibachi',
#     'location': {'address': '1863 86th St',
#      'crossStreet': 'at 19th Ave.',
#      'lat': 40.606545000000004,
#      'lng': -74.000928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.606545000000004,
#        'lng': -74.000928}],
#      'distance': 11827,
#      'postalCode': '11214',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1863 86th St (at 19th Ave.)',
#       'Brooklyn, NY 11214',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fbfb2ece4b0a6eab8ea41b8',
#     'name': 'Fuji Japanese Cuisine',
#     'location': {'address': '11327 Queens Blvd',
#      'lat': 40.71732903550111,
#      'lng': -73.83508485694878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71732903550111,
#        'lng': -73.83508485694878}],
#      'distance': 14431,
#      'postalCode': '11375',
#      'cc': 'US',
#      'city': 'Forest Hills',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['11327 Queens Blvd',
#       'Forest Hills, NY 11375',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '446654',
#      'url': 'https://www.seamless.com/menu/fuji-japanese-cuisine-113-27-queens-blvd-forest-hills/446654?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=446654',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ba56d65f964a520020639e3',
#     'name': 'Mikado Japanese Cuisine',
#     'location': {'address': '1734 Sheepshead Bay Rd',
#      'lat': 40.585159000000004,
#      'lng': -73.951663,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.585159000000004,
#        'lng': -73.951663}],
#      'distance': 14924,
#      'postalCode': '11235',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1734 Sheepshead Bay Rd',
#       'Brooklyn, NY 11235',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4dbf11bd41b76bef9276ca',
#     'name': 'Akiyama Japanese Gourmet Restaurant',
#     'location': {'address': '13216 14th Ave',
#      'lat': 40.78582,
#      'lng': -73.836034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78582,
#        'lng': -73.836034}],
#      'distance': 16483,
#      'postalCode': '11356',
#      'cc': 'US',
#      'city': 'College Point',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['13216 14th Ave',
#       'College Point, NY 11356',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b75af66f964a520e31c2ee3',
#     'name': 'Sanma Japanese Restaurant',
#     'location': {'address': '10 Akron St',
#      'crossStreet': 'at Jennifer Place',
#      'lat': 40.61180973836901,
#      'lng': -74.15874947034513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.61180973836901,
#        'lng': -74.15874947034513}],
#      'distance': 17103,
#      'postalCode': '10314',
#      'cc': 'US',
#      'city': 'Staten Island',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Akron St (at Jennifer Place)',
#       'Staten Island, NY 10314',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '471874',
#      'url': 'https://www.seamless.com/menu/sanma-10-akron-st-staten-island/471874?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=471874',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e1e3cfdc65bd9e1fddc9450',
#     'name': 'River Japanese Cuisine',
#     'location': {'address': '61-44 Springfield Blvd',
#      'lat': 40.74802759297992,
#      'lng': -73.7563485681792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74802759297992,
#        'lng': -73.7563485681792}],
#      'distance': 21424,
#      'postalCode': '11364',
#      'cc': 'US',
#      'city': 'Bayside',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['61-44 Springfield Blvd',
#       'Bayside, NY 11364',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1299608',
#      'url': 'https://www.seamless.com/menu/river-japanese-cuisine-6144-springfield-blvd-oakland-gardens/1299608?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1299608',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c238810502b9521383a6e21',
#     'name': 'Harusame Japanese Cuisine',
#     'location': {'address': '63 Academy St',
#      'lat': 40.744131,
#      'lng': -74.258481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744131,
#        'lng': -74.258481}],
#      'distance': 21582,
#      'postalCode': '07079',
#      'cc': 'US',
#      'city': 'South Orange',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['63 Academy St',
#       'South Orange, NJ 07079',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '390483',
#      'url': 'https://www.grubhub.com/restaurant/harusame-japanese-cuisine-63-academy-st-south-orange/390483?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=390483',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bda0cbfaae4ef3b3dcc6ec6',
#     'name': 'TOMO Japanese Cuisine',
#     'location': {'address': '4561A Amboy Rd.',
#      'lat': 40.54283524941763,
#      'lng': -74.16557764794854,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.54283524941763,
#        'lng': -74.16557764794854}],
#      'distance': 23225,
#      'postalCode': '10312',
#      'cc': 'US',
#      'city': 'Staten Island',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4561A Amboy Rd.',
#       'Staten Island, NY 10312',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '274561',
#      'url': 'https://www.seamless.com/menu/tomo-japanese-restaurant-4561-amboy-rd-staten-island/274561?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=274561',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd4a5885631c9b62dd4a230',
#     'name': 'Mt. Fuji Japanese Steak House',
#     'location': {'address': '193 Rt 17 South',
#      'lat': 40.85641097630499,
#      'lng': -74.07050038693424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.85641097630499,
#        'lng': -74.07050038693424},
#       {'label': 'entrance', 'lat': 40.856454, 'lng': -74.070342}],
#      'distance': 16892,
#      'postalCode': '07604',
#      'cc': 'US',
#      'city': 'Hasbrouck Heights',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['193 Rt 17 South',
#       'Hasbrouck Heights, NJ 07604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '120181766'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c7eeb40fb74236ab3b9f8b9',
#     'name': 'Sapporo Sushi & Japanese Steakhouse',
#     'location': {'address': '4 Alvin Pl',
#      'lat': 40.836472011166315,
#      'lng': -74.20741248672886,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.836472011166315,
#        'lng': -74.20741248672886}],
#      'distance': 21863,
#      'postalCode': '07043',
#      'cc': 'US',
#      'city': 'Montclair',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['4 Alvin Pl',
#       'Montclair, NJ 07043',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd77ac235aad13a2b0b8ff3',
#     'name': "Edo's Japanese Steakhouse",
#     'location': {'address': '4787 Boston Post Rd',
#      'lat': 40.896951445591746,
#      'lng': -73.80410574503182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.896951445591746,
#        'lng': -73.80410574503182},
#       {'label': 'entrance', 'lat': 40.897036, 'lng': -73.804032}],
#      'distance': 26645,
#      'postalCode': '10803',
#      'cc': 'US',
#      'city': 'Pelham',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4787 Boston Post Rd',
#       'Pelham, NY 10803',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2292138',
#      'url': 'https://www.seamless.com/menu/edo-japanese-steakhouse-4787-boston-post-rd-pelham-manor/2292138?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2292138',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4dbdf3d790a02849cbd675be',
#     'name': 'Ohana Japanese Habachi Seafood & Steakhouse',
#     'location': {'address': '500 City Island Ave',
#      'crossStreet': 'at Beach St',
#      'lat': 40.85215113102018,
#      'lng': -73.78896162771034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.85215113102018,
#        'lng': -73.78896162771034},
#       {'label': 'entrance', 'lat': 40.852193, 'lng': -73.789032}],
#      'distance': 23991,
#      'postalCode': '10464',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['500 City Island Ave (at Beach St)',
#       'Bronx, NY 10464',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd3725cb221c9b672ced9d0',
#     'name': 'Nihon Kai Japanese Cuisine',
#     'location': {'address': '41 S Washington Ave',
#      'lat': 40.92639295176459,
#      'lng': -73.99640363339813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.92639295176459,
#        'lng': -73.99640363339813},
#       {'label': 'entrance', 'lat': 40.92636, 'lng': -73.996348}],
#      'distance': 23798,
#      'postalCode': '07621',
#      'cc': 'US',
#      'city': 'Bergenfield',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['41 S Washington Ave',
#       'Bergenfield, NJ 07621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '323341',
#      'url': 'https://www.grubhub.com/restaurant/nihon-kai-41-s-washington-ave-bergenfield/323341?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=323341',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get Relevant Part of JSON and Transform it into a pandas Dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_nyc = json_normalize(venues)

# check numbers of results returned
df_nyc.shape
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
# (50, 25)

# %% [markdown]
# #### Second Verse, Same as the First...

# %%
# Foursquare venues->search -> Scarsdale, NY

LIMIT = 100 # limit of number of venues returned by Foursquare API (Maximum 50 resposes)
search_query = 'Japanese'
radius =100000 # define radius
category = '4d4b7105d754a06374d81259' # Food

# create URL
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&query={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    search_query,
    category,
    latitude_scr, 
    longitude_scr,
    radius, 
    LIMIT)

url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/search?&client_id=HFIG5BPXXFM0ISH1XNCAY5K52B5FPFCBBI51Z04UT13U412X&client_secret=CBSE1R4EOGTXSC2J1HKW4R3TJMYHXIFQGLY4PHIA0ZAE1O0A&v=20200804&query=Japanese&categoryId=4d4b7105d754a06374d81259&ll=40.9690798,-73.7635316&radius=100000&limit=100'

# %%
# get request for results
results = requests.get(url).json()

# check numbers of results returned
results   # display results
# Out:
# {'meta': {'code': 200, 'requestId': '5f4a648a539a1348c565f2ef'},
#  'response': {'venues': [{'id': '516e9e7ee4b00e4457f937ec',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '159 Main Street',
#      'lat': 41.03243055533406,
#      'lng': -73.7688248686135,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.03243055533406,
#        'lng': -73.7688248686135}],
#      'distance': 7066,
#      'postalCode': '10601',
#      'cc': 'US',
#      'city': 'White Plains',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['159 Main Street',
#       'White Plains, NY 10601',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ccb57d372106dcb8c939399',
#     'name': 'Sazan Japanese Restaurant',
#     'location': {'address': '729 Saw Mill River Rd',
#      'lat': 41.01344711439348,
#      'lng': -73.84472436982699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.01344711439348,
#        'lng': -73.84472436982699}],
#      'distance': 8422,
#      'postalCode': '10502',
#      'cc': 'US',
#      'city': 'Ardsley',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['729 Saw Mill River Rd',
#       'Ardsley, NY 10502',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2174824',
#      'url': 'https://www.seamless.com/menu/sazan-japanese-restaurant-729-saw-mill-river-road-ardsley/2174824?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2174824',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd77ac235aad13a2b0b8ff3',
#     'name': "Edo's Japanese Steakhouse",
#     'location': {'address': '4787 Boston Post Rd',
#      'lat': 40.896951445591746,
#      'lng': -73.80410574503182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.896951445591746,
#        'lng': -73.80410574503182},
#       {'label': 'entrance', 'lat': 40.897036, 'lng': -73.804032}],
#      'distance': 8724,
#      'postalCode': '10803',
#      'cc': 'US',
#      'city': 'Pelham',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4787 Boston Post Rd',
#       'Pelham, NY 10803',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2292138',
#      'url': 'https://www.seamless.com/menu/edo-japanese-steakhouse-4787-boston-post-rd-pelham-manor/2292138?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2292138',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4cb0edfbeb65b1f7e3a070cd',
#     'name': 'Kicho Japanese Restaraunt',
#     'location': {'lat': 41.04291,
#      'lng': -73.74750361666666,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.04291,
#        'lng': -73.74750361666666}],
#      'distance': 8328,
#      'postalCode': '10604',
#      'cc': 'US',
#      'city': 'White Plains',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['White Plains, NY 10604', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b4cdb51f964a520eac126e3',
#     'name': 'Abis Japanese Traditional Cuisine',
#     'location': {'address': '381 Greenwich Ave',
#      'lat': 41.02264093744494,
#      'lng': -73.62466403973373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.02264093744494,
#        'lng': -73.62466403973373}],
#      'distance': 13102,
#      'postalCode': '06830',
#      'cc': 'US',
#      'city': 'Greenwich',
#      'state': 'CT',
#      'country': 'United States',
#      'formattedAddress': ['381 Greenwich Ave',
#       'Greenwich, CT 06830',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1255800',
#      'url': 'https://www.grubhub.com/restaurant/abis-japanese-traditional-restaurant-381-greenwich-ave-greenwich/1255800?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1255800',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ca50d1e97c8a1cd247863a5',
#     'name': 'Sakura Garden Japanese Cuisine',
#     'location': {'address': '531 Warburton Ave',
#      'lat': 40.994494267906425,
#      'lng': -73.88238802648455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.994494267906425,
#        'lng': -73.88238802648455}],
#      'distance': 10381,
#      'postalCode': '10706',
#      'cc': 'US',
#      'city': 'Hastings-on-Hudson',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['531 Warburton Ave',
#       'Hastings-on-Hudson, NY 10706',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '477038582'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bba1c4b1261d13a243cea98',
#     'name': 'Narita Japanese Restaurant',
#     'location': {'address': '10708 70th Rd',
#      'crossStreet': 'btw Austin St & Queens Blvd',
#      'lat': 40.72079733718884,
#      'lng': -73.84563896863934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72079733718884,
#        'lng': -73.84563896863934}],
#      'distance': 28490,
#      'postalCode': '11375',
#      'cc': 'US',
#      'city': 'Forest Hills',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10708 70th Rd (btw Austin St & Queens Blvd)',
#       'Forest Hills, NY 11375',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4dbdf3d790a02849cbd675be',
#     'name': 'Ohana Japanese Habachi Seafood & Steakhouse',
#     'location': {'address': '500 City Island Ave',
#      'crossStreet': 'at Beach St',
#      'lat': 40.85215113102018,
#      'lng': -73.78896162771034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.85215113102018,
#        'lng': -73.78896162771034},
#       {'label': 'entrance', 'lat': 40.852193, 'lng': -73.789032}],
#      'distance': 13191,
#      'postalCode': '10464',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['500 City Island Ave (at Beach St)',
#       'Bronx, NY 10464',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b6a3399f964a520cfcc2be3',
#     'name': 'Edo Japanese Steakhouse',
#     'location': {'address': '140 Midland Ave',
#      'lat': 40.991667154063514,
#      'lng': -73.67010441295021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.991667154063514,
#        'lng': -73.67010441295021},
#       {'label': 'entrance', 'lat': 40.991548, 'lng': -73.669636}],
#      'distance': 8244,
#      'postalCode': '10573',
#      'cc': 'US',
#      'city': 'Port Chester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['140 Midland Ave',
#       'Port Chester, NY 10573',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2291840',
#      'url': 'https://www.seamless.com/menu/edo-japanese-steakhouse-140-midland-ave-port-chester/2291840?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2291840',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b2ebfbff964a5201fe624e3',
#     'name': 'Ocha Thai & Japanese Cuisine',
#     'location': {'address': '83 Prospect St',
#      'lat': 41.05850816432208,
#      'lng': -73.53585972413877,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.05850816432208,
#        'lng': -73.53585972413877}],
#      'distance': 21559,
#      'postalCode': '06901',
#      'cc': 'US',
#      'city': 'Stamford',
#      'state': 'CT',
#      'country': 'United States',
#      'formattedAddress': ['83 Prospect St',
#       'Stamford, CT 06901',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '294589',
#      'url': 'https://www.grubhub.com/restaurant/ocha-83-prospect-st-stamford/294589?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=294589',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4f32492b19836c91c7c8ae2f',
#     'name': 'Fuji Japanese & Chinese Restaurant',
#     'location': {'address': '94 Bedford St',
#      'lat': 41.05599442341199,
#      'lng': -73.53867898214627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.05599442341199,
#        'lng': -73.53867898214627},
#       {'label': 'entrance', 'lat': 41.056016, 'lng': -73.538812}],
#      'distance': 21220,
#      'postalCode': '06901',
#      'cc': 'US',
#      'city': 'Stamford',
#      'state': 'CT',
#      'country': 'United States',
#      'formattedAddress': ['94 Bedford St',
#       'Stamford, CT 06901',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '144864192'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ed9484cbe7be283365bc081',
#     'name': 'Aki Japanese Cuisine & Asian Fusion',
#     'location': {'address': '46 Main St',
#      'lat': 40.83065512012483,
#      'lng': -73.68663514591036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.83065512012483,
#        'lng': -73.68663514591036},
#       {'label': 'entrance', 'lat': 40.830705, 'lng': -73.68656}],
#      'distance': 16712,
#      'postalCode': '11050',
#      'cc': 'US',
#      'city': 'Port Washington',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['46 Main St',
#       'Port Washington, NY 11050',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '598417dadb1d816c64238a96',
#     'name': 'Yoi Sushi Japanese 良日本料理',
#     'location': {'address': '133-22 39th Ave',
#      'lat': 40.7589929,
#      'lng': -73.83364499999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7589929,
#        'lng': -73.83364499999999}],
#      'distance': 24120,
#      'postalCode': '11354',
#      'cc': 'US',
#      'city': 'Flushing',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['133-22 39th Ave',
#       'Flushing, NY 11354',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2188057',
#      'url': 'https://www.seamless.com/menu/yoi-sushi-133-22-39th-ave-flushing/2188057?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2188057',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '434133555'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e6c0c50b61c739ba8636719',
#     'name': 'Kashi Japanese - Huntington',
#     'location': {'address': '12 Elm St',
#      'crossStreet': 'at New York Ave',
#      'lat': 40.87021160791372,
#      'lng': -73.42550334691998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87021160791372,
#        'lng': -73.42550334691998},
#       {'label': 'entrance', 'lat': 40.87018, 'lng': -73.425559}],
#      'distance': 30489,
#      'postalCode': '11743',
#      'cc': 'US',
#      'city': 'Huntington',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['12 Elm St (at New York Ave)',
#       'Huntington, NY 11743',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '708038',
#      'url': 'https://www.grubhub.com/restaurant/kashi-japanese-lounge-12-elm-st-huntington/708038?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=708038',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4dbf11bd41b76bef9276ca',
#     'name': 'Akiyama Japanese Gourmet Restaurant',
#     'location': {'address': '13216 14th Ave',
#      'lat': 40.78582,
#      'lng': -73.836034,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78582,
#        'lng': -73.836034}],
#      'distance': 21293,
#      'postalCode': '11356',
#      'cc': 'US',
#      'city': 'College Point',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['13216 14th Ave',
#       'College Point, NY 11356',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b7c90acf964a520569b2fe3',
#     'name': 'Tomo Japanese Cuisine',
#     'location': {'address': '86-12 A 37th Ave',
#      'crossStreet': 'btwn 86th & 87th St',
#      'lat': 40.75016941828497,
#      'lng': -73.88014969825647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75016941828497,
#        'lng': -73.88014969825647}],
#      'distance': 26272,
#      'postalCode': '11372',
#      'cc': 'US',
#      'city': 'Jackson Heights',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['86-12 A 37th Ave (btwn 86th & 87th St)',
#       'Jackson Heights, NY 11372',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b53a251f964a5209ba527e3',
#     'name': 'East Japanese Restaurant',
#     'location': {'address': '4494 Palisades Center Dr',
#      'crossStreet': 'Palisades Center Mall',
#      'lat': 41.097093491064996,
#      'lng': -73.9562153395111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.097093491064996,
#        'lng': -73.9562153395111}],
#      'distance': 21560,
#      'postalCode': '10994',
#      'cc': 'US',
#      'city': 'West Nyack',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4494 Palisades Center Dr (Palisades Center Mall)',
#       'West Nyack, NY 10994',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1884733',
#      'url': 'https://www.grubhub.com/restaurant/east-japanese-restaurant-4494-palisades-center-drive-west-nyack/1884733?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1884733',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '53d3e9d8498e87e2518f9aba',
#     'name': 'Sendai Japanese Restaurant & Grill',
#     'location': {'address': '178 Kinderkamack Rd',
#      'lat': 40.975609,
#      'lng': -74.02688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.975609,
#        'lng': -74.02688}],
#      'distance': 22145,
#      'postalCode': '07630',
#      'cc': 'US',
#      'city': 'Emerson',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['178 Kinderkamack Rd',
#       'Emerson, NJ 07630',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '517566854'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4be0a131652b0f4778137311',
#     'name': 'Samurai Japanese Sushi & Hibachi Steak House',
#     'location': {'address': '352 S Riverside Ave',
#      'lat': 41.19550702522591,
#      'lng': -73.88260119996968,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.19550702522591,
#        'lng': -73.88260119996968}],
#      'distance': 27113,
#      'postalCode': '10520',
#      'cc': 'US',
#      'city': 'Croton-on-Hudson',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['352 S Riverside Ave',
#       'Croton-on-Hudson, NY 10520',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1124586',
#      'url': 'https://www.grubhub.com/restaurant/samurai-sushi-and-hibachi-steak-house-352-s-riverside-ave-croton-on-hudson/1124586?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1124586',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd3725cb221c9b672ced9d0',
#     'name': 'Nihon Kai Japanese Cuisine',
#     'location': {'address': '41 S Washington Ave',
#      'lat': 40.92639295176459,
#      'lng': -73.99640363339813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.92639295176459,
#        'lng': -73.99640363339813},
#       {'label': 'entrance', 'lat': 40.92636, 'lng': -73.996348}],
#      'distance': 20148,
#      'postalCode': '07621',
#      'cc': 'US',
#      'city': 'Bergenfield',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['41 S Washington Ave',
#       'Bergenfield, NJ 07621',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '323341',
#      'url': 'https://www.grubhub.com/restaurant/nihon-kai-41-s-washington-ave-bergenfield/323341?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=323341',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e1e3cfdc65bd9e1fddc9450',
#     'name': 'River Japanese Cuisine',
#     'location': {'address': '61-44 Springfield Blvd',
#      'lat': 40.74802759297992,
#      'lng': -73.7563485681792,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74802759297992,
#        'lng': -73.7563485681792}],
#      'distance': 24614,
#      'postalCode': '11364',
#      'cc': 'US',
#      'city': 'Bayside',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['61-44 Springfield Blvd',
#       'Bayside, NY 11364',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1299608',
#      'url': 'https://www.seamless.com/menu/river-japanese-cuisine-6144-springfield-blvd-oakland-gardens/1299608?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1299608',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '42055e00f964a5206e1f1fe3',
#     'name': 'EN Japanese Brasserie',
#     'location': {'address': '435 Hudson St',
#      'crossStreet': 'at Leroy St.',
#      'lat': 40.730297083045144,
#      'lng': -74.00695716911856,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.730297083045144,
#        'lng': -74.00695716911856}],
#      'distance': 33566,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['435 Hudson St (at Leroy St.)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1536134',
#      'url': 'https://www.seamless.com/menu/en-japanese-brasserie-435-hudson-st-new-york/1536134?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1536134',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '103057123'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c3b4ae416cb2d7f8b9c02a9',
#     'name': 'Tomo Japanese Cafe',
#     'location': {'address': '8914 Queens Blvd',
#      'crossStreet': 'btwn 56th & 57th Ave.',
#      'lat': 40.734630357172136,
#      'lng': -73.87418166369174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734630357172136,
#        'lng': -73.87418166369174}],
#      'distance': 27711,
#      'postalCode': '11373',
#      'cc': 'US',
#      'city': 'Elmhurst',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['8914 Queens Blvd (btwn 56th & 57th Ave.)',
#       'Elmhurst, NY 11373',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1093832',
#      'url': 'https://www.seamless.com/menu/tomo-japanese-cafe-8914-queens-blvd-elmhurst/1093832?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1093832',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b68bee0f964a520808a2be3',
#     'name': 'Koyama Japanese Restaurant',
#     'location': {'address': '458 Palisade Ave',
#      'lat': 40.819594,
#      'lng': -73.988568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.819594,
#        'lng': -73.988568},
#       {'label': 'entrance', 'lat': 40.819737, 'lng': -73.988594}],
#      'distance': 25208,
#      'postalCode': '07010',
#      'cc': 'US',
#      'city': 'Cliffside Park',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['458 Palisade Ave',
#       'Cliffside Park, NJ 07010',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fb93e46e4b0d0dd7eb666c6',
#     'name': 'Amura Japanese Cuisine',
#     'location': {'address': '1567 2nd Ave',
#      'lat': 40.77492786445796,
#      'lng': -73.95393883303005,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77492786445796,
#        'lng': -73.95393883303005}],
#      'distance': 26907,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1567 2nd Ave',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '268954',
#      'url': 'https://www.seamless.com/menu/amura-1567-2nd-ave-new-york/268954?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=268954',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4c48cafcb5eec9b633f2dfa3',
#     'name': 'Fuki Japanese Restaurant',
#     'location': {'address': '828 Kinderkamack Rd',
#      'lat': 40.93641676595293,
#      'lng': -74.0309893614369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.93641676595293,
#        'lng': -74.0309893614369},
#       {'label': 'entrance', 'lat': 40.936384, 'lng': -74.030892}],
#      'distance': 22778,
#      'postalCode': '07661',
#      'cc': 'US',
#      'city': 'River Edge',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['828 Kinderkamack Rd',
#       'River Edge, NJ 07661',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1724948',
#      'url': 'https://www.grubhub.com/restaurant/fuki-sushi-828-kinderkamack-road-river-edge/1724948?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1724948',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '5006eaf1e4b0d9eeb5cd67ef',
#     'name': 'Atami Japanese Fusion',
#     'location': {'address': '1167 2nd Ave',
#      'lat': 40.762158444759486,
#      'lng': -73.96317393360368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762158444759486,
#        'lng': -73.96317393360368}],
#      'distance': 28513,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1167 2nd Ave',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '461198',
#      'url': 'https://www.seamless.com/menu/atami-japanese-fusion-1167-2nd-ave-new-york/461198?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=461198',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ba55d11f964a5205cff38e3',
#     'name': 'Samurai Japanese Steakhouse',
#     'location': {'address': '46 Gerard St Unit A',
#      'lat': 40.87225726591513,
#      'lng': -73.42774011665675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.87225726591513,
#        'lng': -73.42774011665675}],
#      'distance': 30231,
#      'postalCode': '11743',
#      'cc': 'US',
#      'city': 'Huntington',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['46 Gerard St Unit A',
#       'Huntington, NY 11743',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '423827',
#      'url': 'https://www.grubhub.com/restaurant/samurai-46a-gerard-st-huntington/423827?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=423827',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4a86ffb1f964a520090220e3',
#     'name': 'Osaka Japanese Restaurant',
#     'location': {'address': '24-25 Broadway',
#      'lat': 40.763054033139525,
#      'lng': -73.9276589498208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.763054033139525,
#        'lng': -73.9276589498208}],
#      'distance': 26774,
#      'postalCode': '11106',
#      'cc': 'US',
#      'neighborhood': 'Astoria',
#      'city': 'Astoria',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['24-25 Broadway',
#       'Astoria, NY 11106',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '71415',
#      'url': 'https://www.seamless.com/menu/osaka-japanese-fusion-2524-broadway-ave-astoria/71415?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=71415',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b3958dff964a520115b25e3',
#     'name': 'East Japanese',
#     'location': {'address': '1405 Teaneck Rd',
#      'crossStreet': 'at Beveridge St',
#      'lat': 40.899798872356016,
#      'lng': -73.99964947649333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.899798872356016,
#        'lng': -73.99964947649333},
#       {'label': 'entrance', 'lat': 40.899851, 'lng': -73.999627}],
#      'distance': 21301,
#      'postalCode': '07666',
#      'cc': 'US',
#      'city': 'Teaneck',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['1405 Teaneck Rd (at Beveridge St)',
#       'Teaneck, NJ 07666',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bf9ee16328d76b045b114ec',
#     'name': 'Kumo Japanese Bistro',
#     'location': {'address': '22 S Main St',
#      'lat': 41.05852363793511,
#      'lng': -74.02171957393692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.05852363793511,
#        'lng': -74.02171957393692}],
#      'distance': 23863,
#      'postalCode': '10965',
#      'cc': 'US',
#      'city': 'Pearl River',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['22 S Main St',
#       'Pearl River, NY 10965',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fbfb2ece4b0a6eab8ea41b8',
#     'name': 'Fuji Japanese Cuisine',
#     'location': {'address': '11327 Queens Blvd',
#      'lat': 40.71732903550111,
#      'lng': -73.83508485694878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71732903550111,
#        'lng': -73.83508485694878}],
#      'distance': 28665,
#      'postalCode': '11375',
#      'cc': 'US',
#      'city': 'Forest Hills',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['11327 Queens Blvd',
#       'Forest Hills, NY 11375',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '446654',
#      'url': 'https://www.seamless.com/menu/fuji-japanese-cuisine-113-27-queens-blvd-forest-hills/446654?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=446654',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '558bca73498e29a61bcb2ce6',
#     'name': 'T & O Thai and Japanese Restaurant',
#     'location': {'address': '140 Jericho Tpke Syosset  11791',
#      'lat': 40.809472,
#      'lng': -73.511359,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.809472,
#        'lng': -73.511359}],
#      'distance': 27677,
#      'postalCode': '11791',
#      'cc': 'US',
#      'city': 'Syosset',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['140 Jericho Tpke Syosset  11791',
#       'Syosset, NY 11791',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '151546538'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4ef0d81fbe7ba3ed7c2296d2',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '321 W 44th St',
#      'crossStreet': 'btwn 8th & 9th Ave',
#      'lat': 40.75904160050783,
#      'lng': -73.99004327793013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75904160050783,
#        'lng': -73.99004327793013}],
#      'distance': 30171,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['321 W 44th St (btwn 8th & 9th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2250480',
#      'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-321-w-44th-st-new-york/2250480?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2250480',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b78ac62f964a52047dd2ee3',
#     'name': 'Zutto Japanese American Pub',
#     'location': {'address': '77 Hudson St',
#      'crossStreet': 'Harrison St and Worth St.',
#      'lat': 40.7185655837561,
#      'lng': -74.00891273768076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7185655837561,
#        'lng': -74.00891273768076},
#       {'label': 'entrance', 'lat': 40.718459, 'lng': -74.009006}],
#      'distance': 34708,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['77 Hudson St (Harrison St and Worth St.)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '867441',
#      'url': 'https://www.seamless.com/menu/zutto-77-hudson-st-new-york/867441?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=867441',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '42701794'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '48208c8cf964a520894f1fe3',
#     'name': 'Gyu-Kaku Japanese BBQ',
#     'location': {'address': '805 3rd Ave',
#      'crossStreet': 'btwn E 49th & E 50th St',
#      'lat': 40.755730504250046,
#      'lng': -73.9708969487331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755730504250046,
#        'lng': -73.9708969487331}],
#      'distance': 29475,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['805 3rd Ave (btwn E 49th & E 50th St)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2251148',
#      'url': 'https://www.seamless.com/menu/gyu-kaku-japanese-bbq-805-3rd-ave-new-york/2251148?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2251148',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bcb5030937ca593f44aa992',
#     'name': 'Chikurin Japanese Restaurant',
#     'location': {'address': '39-11 Queens Blvd',
#      'lat': 40.74433135986328,
#      'lng': -73.92537689208984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74433135986328,
#        'lng': -73.92537689208984}],
#      'distance': 28488,
#      'postalCode': '11104',
#      'cc': 'US',
#      'city': 'Sunnyside',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['39-11 Queens Blvd',
#       'Sunnyside, NY 11104',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e4e4aa6bd4101d0d7a6fc27',
#     'name': 'Asahi Japanese Cuisine',
#     'location': {'address': '311 W 48th St',
#      'lat': 40.76150131225586,
#      'lng': -73.98757934570312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76150131225586,
#        'lng': -73.98757934570312}],
#      'distance': 29827,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['311 W 48th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b5de807f964a520d47229e3',
#     'name': 'Tokyo Japanese Kitchen',
#     'location': {'address': '38-01 31st St',
#      'lat': 40.75345047269599,
#      'lng': -73.9323436512949,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75345047269599,
#        'lng': -73.9323436512949}],
#      'distance': 27895,
#      'postalCode': '11101',
#      'cc': 'US',
#      'city': 'Astoria',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['38-01 31st St',
#       'Astoria, NY 11101',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4acea43cf964a5208ad120e3',
#     'name': "Raku It's Japanese II",
#     'location': {'address': '57 W 76th St',
#      'crossStreet': 'at Columbus Ave',
#      'lat': 40.77999142937673,
#      'lng': -73.97661045826288,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77999142937673,
#        'lng': -73.97661045826288}],
#      'distance': 27654,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['57 W 76th St (at Columbus Ave)',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '284075',
#      'url': 'https://www.seamless.com/menu/raku-ii-japanese-restaurant-57-w-76th-st-new-york/284075?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=284075',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '96183310'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bde28866c1b9521ac51ad0f',
#     'name': 'Ichiban Japanese Restaurant',
#     'location': {'address': '409 8th Ave',
#      'crossStreet': '31st Street',
#      'lat': 40.750082040220704,
#      'lng': -73.99501732393351,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750082040220704,
#        'lng': -73.99501732393351}],
#      'distance': 31211,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['409 8th Ave (31st Street)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4fd91c44e4b0d9021d3ee7ca',
#     'name': "Ai's Sushi Japanese Restaurant",
#     'location': {'address': '374 W 46th St',
#      'crossStreet': '9th Ave',
#      'lat': 40.760777000000004,
#      'lng': -73.990584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.760777000000004,
#        'lng': -73.990584}],
#      'distance': 30050,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['374 W 46th St (9th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4a8cb3fff964a520ed0e20e3',
#     'name': "Ruby's Japanese & Thai",
#     'location': {'address': '259 1st Ave',
#      'crossStreet': 'at E 15th St.',
#      'lat': 40.732248999999996,
#      'lng': -73.982291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.732248999999996,
#        'lng': -73.982291},
#       {'label': 'entrance', 'lat': 40.732195, 'lng': -73.982163}],
#      'distance': 32161,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['259 1st Ave (at E 15th St.)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b5fd5d7f964a52053ce29e3',
#     'name': 'Sakura Japanese Restaurant',
#     'location': {'address': '371 Franklin Ave',
#      'crossStreet': 'at Madison Ave.',
#      'lat': 41.00968162268614,
#      'lng': -74.17050325853391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.00968162268614,
#        'lng': -74.17050325853391},
#       {'label': 'entrance', 'lat': 41.009612, 'lng': -74.170408}],
#      'distance': 34493,
#      'postalCode': '07481',
#      'cc': 'US',
#      'city': 'Wyckoff',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['371 Franklin Ave (at Madison Ave.)',
#       'Wyckoff, NJ 07481',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4baab031f964a520fc7f3ae3',
#     'name': 'Chikurin Japanese Restaurant',
#     'location': {'address': '1777 Ocean Ave',
#      'crossStreet': 'at Ave M',
#      'lat': 40.61873004377748,
#      'lng': -73.95481085897256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.61873004377748,
#        'lng': -73.95481085897256},
#       {'label': 'entrance', 'lat': 40.618744, 'lng': -73.954855}],
#      'distance': 42200,
#      'postalCode': '11230',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1777 Ocean Ave (at Ave M)',
#       'Brooklyn, NY 11230',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '299694',
#      'url': 'https://www.seamless.com/menu/chikurin-japanese-restaurant-1777-ocean-ave-brooklyn/299694?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299694',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4e6aaea3d164c37bf4b2539d',
#     'name': 'Sumo Japanese Cuisine',
#     'location': {'address': '104 John St',
#      'crossStreet': 'at Cliff St',
#      'lat': 40.70771408081055,
#      'lng': -74.0062255859375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70771408081055,
#        'lng': -74.0062255859375}],
#      'distance': 35556,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 John St (at Cliff St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4bd4a5885631c9b62dd4a230',
#     'name': 'Mt. Fuji Japanese Steak House',
#     'location': {'address': '193 Rt 17 South',
#      'lat': 40.85641097630499,
#      'lng': -74.07050038693424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.85641097630499,
#        'lng': -74.07050038693424},
#       {'label': 'entrance', 'lat': 40.856454, 'lng': -74.070342}],
#      'distance': 28708,
#      'postalCode': '07604',
#      'cc': 'US',
#      'city': 'Hasbrouck Heights',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['193 Rt 17 South',
#       'Hasbrouck Heights, NJ 07604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '120181766'},
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b7736b9f964a5206b882ee3',
#     'name': 'Emperor Japanese Tapas Shabu',
#     'location': {'address': '96 Bowery',
#      'crossStreet': 'btw Hester & Grand',
#      'lat': 40.71758147589841,
#      'lng': -73.99533004707291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71758147589841,
#        'lng': -73.99533004707291}],
#      'distance': 34129,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['96 Bowery (btw Hester & Grand)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '4b789da8f964a52052da2ee3',
#     'name': 'Matsuya Japanese Steak House',
#     'location': {'address': '490 Market St',
#      'lat': 40.897248804367344,
#      'lng': -74.10082378375039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.897248804367344,
#        'lng': -74.10082378375039}],
#      'distance': 29471,
#      'postalCode': '07663',
#      'cc': 'US',
#      'city': 'Saddle Brook',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['490 Market St',
#       'Saddle Brook, NJ 07663',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False},
#    {'id': '5230911811d2135985970a3e',
#     'name': 'Mizu Japanese',
#     'location': {'address': '4037 Hempstead Tpke',
#      'lat': 40.72588734754388,
#      'lng': -73.48649413487593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72588734754388,
#        'lng': -73.48649413487593}],
#      'distance': 35736,
#      'postalCode': '11714',
#      'cc': 'US',
#      'city': 'Bethpage',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['4037 Hempstead Tpke',
#       'Bethpage, NY 11714',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1598711077',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df_scr = json_normalize(venues)

# check numbers of results returned
df_scr.shape
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
# (50, 25)

# %% [markdown]
# #### Append the Restaurant Search Results for New York and Scarsdale and Remove Duplicate/Overlapping Entries

# %%
# Append the dataframes
df_append = df_nyc.append([df_scr])

# Remove duplicates
df_nyc_scr = df_append.drop_duplicates(subset=['id'])
df_nyc_scr.shape
print ("No of unique Japanese restaurants identified around New York : " + str(df_nyc_scr.shape[0]))
# Out:
# No of unique Japanese restaurants identified around New York : 71

# %% [markdown]
# #### Select only Relevant Information and Check the Results

# %%
df_rest = df_nyc_scr [['name','location.address','location.city','location.state','location.lat','location.lng']]
df_rest
# Out:
#                                   name                 location.address  \
# 0          Zutto Japanese American Pub                     77 Hudson St
# 1                Sumo Japanese Cuisine                      104 John St
# 2                EN Japanese Brasserie                    435 Hudson St
# 3         Emperor Japanese Tapas Shabu                        96 Bowery
# 4        Pinklady Japanese Cheese Tart                       11 Mott St
# ..                                 ...                              ...
# 30                Kumo Japanese Bistro                     22 S Main St
# 32  T & O Thai and Japanese Restaurant  140 Jericho Tpke Syosset  11791
# 43          Sakura Japanese Restaurant                 371 Franklin Ave
# 48        Matsuya Japanese Steak House                    490 Market St
# 49                       Mizu Japanese              4037 Hempstead Tpke
#
#    location.city location.state  location.lat  location.lng
# 0       New York             NY     40.718566    -74.008913
# 1       New York             NY     40.707714    -74.006226
# 2       New York             NY     40.730297    -74.006957
# 3       New York             NY     40.717581    -73.995330
# 4       New York             NY     40.713986    -73.998741
# ..           ...            ...           ...           ...
# 30   Pearl River             NY     41.058524    -74.021720
# 32       Syosset             NY     40.809472    -73.511359
# 43       Wyckoff             NJ     41.009682    -74.170503
# 48  Saddle Brook             NJ     40.897249    -74.100824
# 49      Bethpage             NY     40.725887    -73.486494
#
# [71 rows x 6 columns]

# %% [markdown]
# This concludes the Data gathering phase of this project.

# %% [markdown]
# ### Methodology

# %% [markdown]
# Now that I have the location details for all Japanese restaurants around New York, I will cluster them using K-Means clustering algorithm. This will give an idea of concentration of Japanese restaurants in New York and the Greater New York area. The clustering will help to identify locations with lesser density of Japanese restaurants. Using the density of population of Japanese people in the area, we can find out the clusters which could be good to open a new Japanese restaurant.

# %% [markdown]
# #### Visualize Japanese Restaurants in New York using Folium

# %%
venues_map = folium.Map(location=[latitude_nyc, longitude_nyc], zoom_start=10) # generate map centred around New York

# add a red circle marker to New York
folium.features.CircleMarker(
    [latitude_nyc, longitude_nyc],
    radius=10,
    color='red',
    popup='New York',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Japanese restaurants as blue circle markers
for lat, lng, label in zip(df_rest['location.lat'], df_rest['location.lng'], df_rest['location.city']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Cluster Neighborhoods using K-Means Clustering Algorithm

# %%
df_lat_lng = df_nyc_scr [['location.lat', 'location.lng']]

# %% [markdown]
# #### K-Means Clustering

# %%
# set number of clusters
kclusters = 5

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_lat_lng)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:71]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 4, 2, 2, 4, 2, 2, 4, 2, 2, 2, 4, 2, 4, 2, 4, 0,
#        2, 0, 0, 4, 4, 0, 3, 3, 3, 1, 3, 1, 1, 1, 4, 1, 3, 0, 3, 0, 1, 0,
#        3, 1, 0, 0, 1], dtype=int32)

# %% [markdown]
# #### Add Cluster Labels to the Dataframe df_rest

# %%
# add clustering labels 
df_rest.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# #### Visualize Clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude_nyc, longitude_nyc], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_rest['location.lat'], df_rest['location.lng'], df_rest['location.city'], df_rest['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Results

# %% [markdown]
# Our analysis using the clusters map shows that there are a greater number of Japanese restaurants in Midtown and Downtown Manhattan, Queens, Westchester, and Bergen County NJ. This makes sense as there are established Japanese communities in these areas.
